# %% [markdown]
# <a href="https://colab.research.google.com/github/De4lerr/Imersao_de_Dados_3/blob/main/Aula2_An%C3%A1lise_de_Compostos_Usando_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![istockphoto-859751268-612x612.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.columns = [coluna.replace('-','') for coluna in dados.columns]
mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# # Desafio 1:
# *Ordenar o gráfico countplot*

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %% [markdown]
# `order = cod_compostos`

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
plt.figure(figsize=(8, 6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'), order = cod_compostos, edgecolor=(0,0,0))
ax.set_title('Top 5 Compostos')
plt.show()

# %% [markdown]
# #Desafio 2:
# *Melhorar a visualização alterando tamanho da fonte*

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
plt.figure(figsize=(8, 6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'), order = cod_compostos, edgecolor=(0,0,0))
ax.set(title='Top 5 Compostos', xlabel = 'Compostos', ylabel = 'Quantidade de Vezes Utilizada')
plt.show()

# %% [markdown]
# #Desafio 3:
# *Plotar os histogramas com seaborn*

# %%
experimentos = dados.drop(['id', 'tratamento',	'tempo',	'dose',	'composto'], axis=1).T
experimentos.columns = dados['id']

# %%
lin_celular = experimentos.T.loc[:,"c0": "c99"]
lin_celular
# Out:
#                   c0      c1      c2      c3  ...     c96     c97     c98     c99
# id                                            ...
# id_000644bb2 -0.0600  0.1083  0.6864  0.4043  ... -0.3981  0.2139  0.3801  0.4176
# id_000779bfc  0.0927  0.2723  0.2772  0.7776  ...  0.1522  0.1241  0.6077  0.7371
# id_000a6266a -0.1312 -1.4640  0.3394 -1.7790  ... -0.6417 -0.2187 -1.4080  0.6931
# id_0015fd391 -0.3998 -4.5520 -2.7350 -1.9630  ... -1.6210 -0.8784 -0.3876 -0.8154
# id_001626bd3 -0.3774  0.7364 -0.1659  0.2341  ...  0.1094  0.2885 -0.3786  0.7125
# ...              ...     ...     ...     ...  ...     ...     ...     ...     ...
# id_fffb1ceed  0.4224  0.1871 -0.4822  0.3713  ...  0.0631  0.9171  0.5258  0.4680
# id_fffb70c0c  0.2144  0.4350  0.1174  1.3960  ... -0.2084 -0.1224 -0.2715  0.3689
# id_fffc1c3f4  1.0650  0.6329  0.3742  0.1237  ...  0.2256  0.7592  0.6656  0.3808
# id_fffcb9e7c  0.5377  1.3240  0.9679  0.1419  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
genes = experimentos.T.loc[:,"g0": "g771"]
genes
# Out:
#                   g0      g1      g2      g3  ...    g768    g769    g770    g771
# id                                            ...
# id_000644bb2  1.0620  0.5577 -0.2479 -0.6208  ...  0.3008  1.6490  0.2968 -0.0224
# id_000779bfc  0.0743  0.4087  0.2991  0.0604  ... -0.1626 -0.3340 -0.3289 -0.2718
# id_000a6266a  0.6280  0.5817  1.5540 -0.0764  ...  0.5797  0.3143  0.8133  0.7923
# id_0015fd391 -0.5138 -0.2491 -0.2656  0.5288  ...  0.1996  0.4374  0.1588 -0.0343
# id_001626bd3 -0.3254 -0.4009  0.9700  0.6919  ... -1.0020 -0.7534  0.5000 -0.6269
# ...              ...     ...     ...     ...  ...     ...     ...     ...     ...
# id_fffb1ceed  0.1394 -0.0636 -0.1112 -0.5080  ...  0.7221  0.5099 -0.1423  0.3806
# id_fffb70c0c -1.3260  0.3478 -0.3743  0.9905  ...  0.5247  0.5438 -0.1875 -0.4751
# id_fffc1c3f4  0.3942  0.3756  0.3109 -0.7389  ...  0.9778  0.2326 -0.6191  0.3603
# id_fffcb9e7c  0.6660  0.2324  0.4392  0.2044  ...  0.1794  0.3109 -0.3491 -0.4741
# ...

# %%
genes.T['id_000644bb2'].hist(bins= 100, edgecolor=(0.2,0.2,0.6))

# %%
lin_celular.T['id_000644bb2'].hist(bins= 100, edgecolor=(0.2,0.2,0.6))

# %%
genes['g1'].hist(bins= 100, edgecolor=(0.2,0.2,0.6))

# %%
lin_celular['c1'].hist(bins= 100, edgecolor=(0.2,0.2,0.6))

# %% [markdown]
# #Desafio 4:
# *Estudar sobre as estatíticas retornadas no `.describe()`*

# %%
lin_celular.describe()
# Out:
#                  c0            c1  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      -0.355156     -0.455359  ...     -0.470252     -0.301505
# std        1.752565      2.004962  ...      1.834828      1.407918
# min      -10.000000    -10.000000  ...    -10.000000    -10.000000
# 25%       -0.549300     -0.538425  ...     -0.592600     -0.562900
# 50%       -0.009000      0.009800  ...      0.014000     -0.019500
# 75%        0.448975      0.476875  ...      0.461275      0.438650
# max        3.365000      3.915000  ...      3.111000      3.805000
#
# [8 rows x 100 columns]

# %%
genes.describe()
# Out:
#                  g0            g1  ...          g770          g771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %% [markdown]
# ##Analisando para as Linhagens Celulares:

# %%
#Analisando a distribuição de valores mínimos
lin_celular.describe().T["min"].hist(bins = 50)

# %%
#Anaslisando a distribuição de valores para o primeiro quartil
lin_celular.describe().T["25%"].hist(bins = 50)

# %%
#Anaslisando a distribuição de valores para o segundo quartil
lin_celular.describe().T["50%"].hist(bins = 50)

# %%
#Anaslisando a distribuição de valores para o terceiro quartil
lin_celular.describe().T["75%"].hist(bins = 50)

# %%
#Analisando a distribuição de valores máximos
lin_celular.describe().T["max"].hist(bins = 50)

# %%
#Dando uma olhada mais a fundo nos valores máximos
lin_celular.describe().T["max"].describe()
# Out:
# count    100.00000
# mean       3.80900
# std        0.73508
# min        2.28900
# 25%        3.30075
# 50%        3.75850
# 75%        4.18675
# max        6.41200
# Name: max, dtype: float64

# %%
#Analisando a distribuição das médias
lin_celular.describe().T["mean"].hist(bins = 50)

# %% [markdown]
# ##Analisando para os Genes:

# %%
#Analisando a distribuição de valores mínimos
genes.describe().T["min"].hist(bins = 50)

# %%
#Anaslisando a distribuição de valores para o primeiro quartil
genes.describe().T["25%"].hist(bins = 50)

# %%
#Anaslisando a distribuição de valores para o segundo quartil
genes.describe().T["50%"].hist(bins = 50)

# %%
#Anaslisando a distribuição de valores para o terceiro quartil
genes.describe().T["75%"].hist(bins = 50)

# %%
#Analisando a distribuição de valores máximos
genes.describe().T["max"].hist(bins = 50)

# %%
#Analisando a distribuição das médias
genes.describe().T["mean"].hist(bins = 50)

# %% [markdown]
# ##Resultados:

# %% [markdown]
# * Valores normalizados (média e mediana girando em torno de 0, com valores máximos sendo 10 e mínimos sendo -10, além dos gráficos em formato campanolar)
# * Valor máximo absoluto das linhagens celulares é 6.412, e não 10, sendo que a maioria dos valores máximos giram em torno de 4, porém possuem min. absoluto de -10 tal qual os genes, e a maioria das linhagens possuem valor min de -10
# * Maioria dos genes possuem média do valor de suas expressões em torno de 0, enquanto a média dos valores de expressão para as linhagens celulares flutuam, em sua maioria, entre -0.5 e -0.4

# %% [markdown]
# #Desafio 5:
# *Refletir sobre a manipulação do tamanho das visualizações*

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='g0', y='tratamento' , data=dados)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='g0', x='tratamento' , data=dados)

# %% [markdown]
# Notamos que ao inverter a orientação do boxplot, modificamos a proporção dos intervalos, o que causou um afastamento visual maior dos boxplot em relação ao 0, oque nos mostra que apenas gráficos não nos servem para analisar um problema, já que a informação que tiramos de apenas um gráfico pode variar pela proporção. Por exemplo:

# %%
plt.figure(figsize=(50,15))
sns.boxplot(x='g0', y='tratamento' , data=dados)

# %% [markdown]
# #Desafio 6:
# *Fazer outras análises com o boxplot e até com o histograma*

# %%
plt.figure(figsize=(7, 7))
sns.boxplot(x='c0', y='tratamento' , data=dados)

# %%
plt.figure(figsize=(7, 7))
sns.boxplot(x='c99', y='tratamento' , data=dados)

# %%
plt.figure(figsize=(7, 7))
sns.boxplot(x='g75', y='tratamento' , data=dados)

# %%
plt.figure(figsize=(7, 7))
sns.boxplot(x='g267', y='tratamento' , data=dados)

# %%
plt.figure(figsize=(7, 7))
sns.boxplot(x='g355', y='tratamento' , data=dados)

# %%
genes["g355"].hist(bins = 100)

# %%
plt.figure(figsize=(7, 7))
sns.boxplot(x='g0', y='dose' , data=dados)

# %%
plt.figure(figsize=(7, 7))
sns.boxplot(x='g599', y='dose' , data=dados)

# %% [markdown]
# ##Resultados:
# * Aparentemente a mediana dos valores de expressão para tratametos com droga é bem próxima da mediana das tratadas com controle.
# * Novamente as linhagens celulares apresentam, em sua maioria, variação entre -10 e 6, ficando ainda mais claro com os boxplots, já que há uma grande concentração de outliners abaixo do mesmo.
# * A quantidade de outliners para tratamentos com controle são menores que os tratados com drogas, diferente das expressões para diferentes doses, que possuem boxplots bastante semelhantes para as duas doses usadas.

# %% [markdown]
# #Desafio 7:
# *Resumo do que você aprendeu com os dados*

# %% [markdown]
# ![imagem_2021-05-04_202853.png](data:image/png;base64,...)

# %% [markdown]
# Ao final dessa análise, pude entender que os dados foram normalizados, transformados para que sua média se tornasse 0, e como esse processo facilita a visualização e obtenção de resultados a partir dos dados. E como os gráficos ajudam na visualização de informações qualitativas a respeito dos dados.
#
# Pude entender mais um pouco, também, sobre como o boxplot e o histograma podem auxiliar na obtenção de informação a partir de uma base de dados, e como analisá-los devidamente.
